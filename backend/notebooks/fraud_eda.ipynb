# %%
# importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats

# %%
df = pd.read_csv(r"D:\AegisAI\creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# checking the data types, basic information, null values and all.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.175161e-15  3.384974e-16 -1.379537e-15  2.094852e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.021879e-15  1.494498e-15 -5.620335e-16  1.149614e-16 -2.414189e-15
# ...

# %%
# checking the value counts for fraud and non-fraud transactions
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
df[df['Class']==1]
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
# imbalance analysis
fraud_ratio = df['Class'].value_counts(normalize=True)
print(fraud_ratio)
# Out:
# Class
# 0    0.998273
# 1    0.001727
# Name: proportion, dtype: float64

# %%
sns.countplot(x='Class', data=df)
plt.title("Fraud vs Non-Fraud Distribution")
plt.show()

# %% [markdown]
# ### **Output:**
#
# 1. Dataset is extremely imbalanced.
#
# 2. Accuracy is misleading metric.
#
# 3. Precision-Recall & ROC-AUC are better.

# %%
# Statistical Analysis:

fraud = df[df['Class'] == 1]
non_fraud = df[df['Class'] == 0]

output = list(stats.ttest_ind(fraud['Amount'], non_fraud['Amount']))
print(output)
# Out:
# [np.float64(3.00555231397141), np.float64(0.002651220649191686)]

# %%
# Correlation Matrix

plt.figure(figsize=(12,10))
sns.heatmap(df.corr(), cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %%
# Outlier Analysis

sns.boxplot(x='Class', y='Amount', data=df)
plt.show()

# %%
# data is highly skewed, that's why using log transformation

df['Amount_log'] = np.log1p(df['Amount'])

# %%
from sklearn.preprocessing import StandardScaler

# %%
df['Amount'].skew()
sns.histplot(df['Amount_log'])
# Out:
# <Axes: xlabel='Amount_log', ylabel='Count'>

# %% [markdown]
# ### **Baseline Model (Logistic Regression)**

# %%
# STEP 1 — Train-Test Split (Stratified)


from sklearn.model_selection import train_test_split

X = df.drop("Class", axis=1)
y = df["Class"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

print("Train Fraud Ratio:", y_train.mean())
print("Test Fraud Ratio:", y_test.mean())
# Out:
# Train Fraud Ratio: 0.001729245759178389
# Test Fraud Ratio: 0.0017204452090867595

# %%
# STEP 2 — Log Transform Amount

X_train["Amount"] = np.log1p(X_train["Amount"])
X_test["Amount"] = np.log1p(X_test["Amount"])

# %%
# STEP 3 — Scale Only Amount

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train["Amount"] = scaler.fit_transform(X_train[["Amount"]])
X_test["Amount"] = scaler.transform(X_test[["Amount"]])

# %%
# STEP 4 — Train Logistic Regression (Class Weighted)

from sklearn.linear_model import LogisticRegression

model = LogisticRegression(class_weight="balanced", max_iter=1000)
model.fit(X_train, y_train)
# Out:
# c:\Users\kunal\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 1000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=1000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(class_weight='balanced', max_iter=1000)

# %%
# STEP 5 — Predictions

y_pred = model.predict(X_test)
y_prob = model.predict_proba(X_test)[:, 1]

# %%
# STEP 6 — Evaluation Metrics

from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    roc_auc_score,
    precision_recall_curve,
    auc
)

print(classification_report(y_test, y_pred))

print("ROC-AUC:", roc_auc_score(y_test, y_prob))

precision, recall, _ = precision_recall_curve(y_test, y_prob)
pr_auc = auc(recall, precision)

print("PR-AUC:", pr_auc)

print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     56864
#            1       0.06      0.92      0.11        98
#
#     accuracy                           0.98     56962
#    macro avg       0.53      0.95      0.55     56962
# weighted avg       1.00      0.98      0.99     56962
#
# ROC-AUC: 0.9709848345641013
# PR-AUC: 0.7466630162580639
# Confusion Matrix:
#  [[55454  1410]
#  [    8    90]]

# %%
import numpy as np

threshold = 0.6
y_pred_custom = (y_prob > threshold).astype(int)

from sklearn.metrics import classification_report, confusion_matrix

print("Threshold:", threshold)
print(classification_report(y_test, y_pred_custom))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_custom))
# Out:
# Threshold: 0.6
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     56864
#            1       0.09      0.91      0.16        98
#
#     accuracy                           0.98     56962
#    macro avg       0.54      0.95      0.58     56962
# weighted avg       1.00      0.98      0.99     56962
#
# Confusion Matrix:
#  [[55933   931]
#  [    9    89]]

# %%
import numpy as np

threshold = 0.7
y_pred_custom = (y_prob > threshold).astype(int)

from sklearn.metrics import classification_report, confusion_matrix

print("Threshold:", threshold)
print(classification_report(y_test, y_pred_custom))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_custom))
# Out:
# Threshold: 0.7
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     56864
#            1       0.12      0.91      0.22        98
#
#     accuracy                           0.99     56962
#    macro avg       0.56      0.95      0.61     56962
# weighted avg       1.00      0.99      0.99     56962
#
# Confusion Matrix:
#  [[56228   636]
#  [    9    89]]

# %%
import numpy as np

threshold = 0.8
y_pred_custom = (y_prob > threshold).astype(int)

from sklearn.metrics import classification_report, confusion_matrix

print("Threshold:", threshold)
print(classification_report(y_test, y_pred_custom))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_custom))
# Out:
# Threshold: 0.8
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     56864
#            1       0.16      0.89      0.27        98
#
#     accuracy                           0.99     56962
#    macro avg       0.58      0.94      0.63     56962
# weighted avg       1.00      0.99      0.99     56962
#
# Confusion Matrix:
#  [[56406   458]
#  [   11    87]]

# %%
import numpy as np

threshold = 0.9
y_pred_custom = (y_prob > threshold).astype(int)

from sklearn.metrics import classification_report, confusion_matrix

print("Threshold:", threshold)
print(classification_report(y_test, y_pred_custom))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_custom))
# Out:
# Threshold: 0.9
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.25      0.89      0.39        98
#
#     accuracy                           1.00     56962
#    macro avg       0.62      0.94      0.69     56962
# weighted avg       1.00      1.00      1.00     56962
#
# Confusion Matrix:
#  [[56598   266]
#  [   11    87]]

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve

precision, recall, thresholds = precision_recall_curve(y_test, y_prob)

plt.plot(thresholds, precision[:-1], label="Precision")
plt.plot(thresholds, recall[:-1], label="Recall")
plt.xlabel("Threshold")
plt.legend()
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(
    n_estimators=200,
    class_weight="balanced",
    random_state=42,
    n_jobs=-1
)

rf_model.fit(X_train, y_train)

y_pred_rf = rf_model.predict(X_test)
y_prob_rf = rf_model.predict_proba(X_test)[:, 1]

from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

print(classification_report(y_test, y_pred_rf))
print("ROC-AUC:", roc_auc_score(y_test, y_prob_rf))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.96      0.76      0.85        98
#
#     accuracy                           1.00     56962
#    macro avg       0.98      0.88      0.92     56962
# weighted avg       1.00      1.00      1.00     56962
#
# ROC-AUC: 0.9522982870694704
# Confusion Matrix:
#  [[56861     3]
#  [   24    74]]

# %%
y_prob_rf = rf_model.predict_proba(X_test)[:, 1]

threshold = 0.3  # try lower than 0.5
y_pred_custom_rf = (y_prob_rf > threshold).astype(int)

from sklearn.metrics import classification_report, confusion_matrix

print("Threshold:", threshold)
print(classification_report(y_test, y_pred_custom_rf))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_custom_rf))
# Out:
# Threshold: 0.3
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.94      0.83      0.88        98
#
#     accuracy                           1.00     56962
#    macro avg       0.97      0.91      0.94     56962
# weighted avg       1.00      1.00      1.00     56962
#
# Confusion Matrix:
#  [[56859     5]
#  [   17    81]]

# %%
y_prob_rf = rf_model.predict_proba(X_test)[:, 1]

threshold = 0.4 # try lower than 0.5
y_pred_custom_rf = (y_prob_rf > threshold).astype(int)

from sklearn.metrics import classification_report, confusion_matrix

print("Threshold:", threshold)
print(classification_report(y_test, y_pred_custom_rf))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_custom_rf))
# Out:
# Threshold: 0.4
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.95      0.79      0.86        98
#
#     accuracy                           1.00     56962
#    macro avg       0.98      0.89      0.93     56962
# weighted avg       1.00      1.00      1.00     56962
#
# Confusion Matrix:
#  [[56860     4]
#  [   21    77]]

# %%
y_prob_rf = rf_model.predict_proba(X_test)[:, 1]

threshold = 0.45  # try lower than 0.5
y_pred_custom_rf = (y_prob_rf > threshold).astype(int)

from sklearn.metrics import classification_report, confusion_matrix

print("Threshold:", threshold)
print(classification_report(y_test, y_pred_custom_rf))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_custom_rf))
# Out:
# Threshold: 0.45
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.95      0.78      0.85        98
#
#     accuracy                           1.00     56962
#    macro avg       0.97      0.89      0.93     56962
# weighted avg       1.00      1.00      1.00     56962
#
# Confusion Matrix:
#  [[56860     4]
#  [   22    76]]

# %% [markdown]
# **Install XGBoost**

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from xgboost import XGBClassifier

xgb_model = XGBClassifier(
    n_estimators=300,
    max_depth=5,
    learning_rate=0.05,
    scale_pos_weight=len(y_train[y_train==0]) / len(y_train[y_train==1]),
    random_state=42,
    n_jobs=-1
)

xgb_model.fit(X_train, y_train)

y_pred_xgb = xgb_model.predict(X_test)
y_prob_xgb = xgb_model.predict_proba(X_test)[:, 1]

from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

print(classification_report(y_test, y_pred_xgb))
print("ROC-AUC:", roc_auc_score(y_test, y_prob_xgb))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.71      0.85      0.77        98
#
#     accuracy                           1.00     56962
#    macro avg       0.85      0.92      0.89     56962
# weighted avg       1.00      1.00      1.00     56962
#
# ROC-AUC: 0.9746229456892492
# Confusion Matrix:
#  [[56830    34]
#  [   15    83]]

# %% [markdown]
# **Tune threshold for XGBoost.**

# %%
threshold = 0.6
y_pred_custom_xgb = (y_prob_xgb > threshold).astype(int)

print("Threshold:", threshold)
print(classification_report(y_test, y_pred_custom_xgb))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_custom_xgb))
# Out:
# Threshold: 0.6
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.78      0.84      0.81        98
#
#     accuracy                           1.00     56962
#    macro avg       0.89      0.92      0.90     56962
# weighted avg       1.00      1.00      1.00     56962
#
# Confusion Matrix:
#  [[56841    23]
#  [   16    82]]

# %%
threshold = 0.7
y_pred_custom_xgb = (y_prob_xgb > threshold).astype(int)

print("Threshold:", threshold)
print(classification_report(y_test, y_pred_custom_xgb))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_custom_xgb))
# Out:
# Threshold: 0.7
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.82      0.83      0.82        98
#
#     accuracy                           1.00     56962
#    macro avg       0.91      0.91      0.91     56962
# weighted avg       1.00      1.00      1.00     56962
#
# Confusion Matrix:
#  [[56846    18]
#  [   17    81]]

# %%
threshold = 0.8
y_pred_custom_xgb = (y_prob_xgb > threshold).astype(int)

print("Threshold:", threshold)
print(classification_report(y_test, y_pred_custom_xgb))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_custom_xgb))
# Out:
# Threshold: 0.8
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.83      0.83      0.83        98
#
#     accuracy                           1.00     56962
#    macro avg       0.91      0.91      0.91     56962
# weighted avg       1.00      1.00      1.00     56962
#
# Confusion Matrix:
#  [[56847    17]
#  [   17    81]]

# %%
threshold = 0.9
y_pred_custom_xgb = (y_prob_xgb > threshold).astype(int)

print("Threshold:", threshold)
print(classification_report(y_test, y_pred_custom_xgb))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_custom_xgb))
# Out:
# Threshold: 0.9
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.89      0.80      0.84        98
#
#     accuracy                           1.00     56962
#    macro avg       0.94      0.90      0.92     56962
# weighted avg       1.00      1.00      1.00     56962
#
# Confusion Matrix:
#  [[56854    10]
#  [   20    78]]

# %%
df2 = df[df['Class']==1]

# %%
df2.to_csv('new.csv')
